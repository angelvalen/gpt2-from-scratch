# %% [markdown]
# # Paraphrase detection training on kaggle

# %%
# !git clone https://github.com/angelvalen/gpt2-from-scratch.git
# %cd gpt2-from-scratch

# %%
# !pip install -r requirements.txt

# %%
# Ensure GPU
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")

# %%
# Training
# Tried full-model on kaggle and calculated ~ 15h training, on last-linear-layer ~4,5h.
# !python paraphrase_detection.py --fine-tune-mode last-linear-layer --use_gpu --paraphrase_dropout_prob 0.1

# %%
# Saving
# !zip -r /kaggle/working/paraphrase_scores.zip /kaggle/working/gpt2-from-scratch/paraphrase_scores
# !zip -r /kaggle/working/predictions.zip /kaggle/working/gpt2-from-scratch/predictions
