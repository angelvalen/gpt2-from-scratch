# %% [markdown]
# # Sonnet generation training on kaggle

# %% [markdown]
# NOTE: Still have to add proper saving for sonnet gen, best_dev model loading, and maybe improve generation.

# %%
# !git clone https://github.com/angelvalen/gpt2-from-scratch.git
# %cd gpt2-from-scratch

# %%
# !pip install -r requirements.txt

# %%
# Ensure GPU
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")

# %%
# Top p sampling
# !python sonnet_generation.py --use_gpu --generation_method top_p

# %%
# Beam search
# !python sonnet_generation.py --use_gpu --generation_method beam
