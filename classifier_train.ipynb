# %%
# Go to dir
# !git clone https://github.com/angelvalen/gpt2-from-scratch.git
# %cd /content/gpt2-from-scratch
# Out:
# Cloning into 'gpt2-from-scratch'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 72 (delta 21), reused 67 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 30.83 MiB | 18.84 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/gpt2-from-scratch

# %%
# Ensure GPU
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# True
# Tesla T4

# %%
# Train on last linear layer (lr=1e-3, dropout=0.3)
# !python classifier.py --fine-tune-mode last-linear-layer --use_gpu

# %%
# Train on full params
# !python classifier.py --fine-tune-mode full-model --use_gpu --hidden_dropout_prob 0.1 --lr 1e-5
# Out:
# Training Sentiment Classifier on SST...
# load 8544 data from data/ids-sst-train.csv
# load 1101 data from data/ids-sst-dev.csv
# ...
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 119kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 6.91MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 3.01MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 10.3MB/s]
# config.json: 100% 665/665 [00:00<00:00, 3.85MB/s]
#
# model.safetensors: downloading bytes:  17% 94.7M/548M [00:00<00:02, 170MB/s, 5.51MB/s  ]
# model.safetensors: downloading bytes:  49% 268M/548M [00:01<00:00, 311MB/s, 21.7MB/s  ]
# model.safetensors: downloading bytes:  65% 358M/548M [00:01<00:00, 251MB/s, 31.3MB/s  ]  ]
# model.safetensors: downloading bytes:  84% 460M/548M [00:02<00:00, 242MB/s, 40.1MB/s  ] ]
# model.safetensors: reconstructing file:  73% 402M/548M [00:02<00:00, 210MB/s, 25.1MB/s  ]
# model.safetensors: downloading bytes: 100% 474M/474M [00:02<00:00, 173MB/s, 41.7MB/s  ] ]
# ...

# %%
# !zip -r scores.zip sentiment_scores/
# !zip -r predictions.zip predictions/
# Out:
#   adding: scores/ (stored 0%)
#   adding: scores/2026-08-11_13-17.json (deflated 52%)
#   adding: scores/2026-08-11_13-52.json (deflated 52%)
#   adding: predictions/ (stored 0%)
#   adding: predictions/full-model-cfimdb-test-out.csv (deflated 46%)
#   adding: predictions/full-model-cfimdb-dev-out.csv (deflated 46%)
#   adding: predictions/full-model-sst-dev-out.csv (deflated 46%)
#   adding: predictions/full-model-sst-test-out.csv (deflated 46%)
#   adding: predictions/README (deflated 25%)

# %%
# Connect to drive for saving predictions
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Save predictions
# !cp /content/gpt2-from-scratch/scores.zip /content/drive/MyDrive/
# !cp /content/gpt2-from-scratch/predictions.zip /content/drive/MyDrive/
